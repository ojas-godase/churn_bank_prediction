# %%
import pandas as pd 
import numpy as np
from sklearn.preprocessing import LabelEncoder , OneHotEncoder , StandardScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("data.csv")
data = data.iloc[: , 1:]
data
# Out:
#       credit_score  country  gender  age  tenure    balance  products_number  \
# 0              619   France  Female   42       2       0.00                1
# 1              608    Spain  Female   41       1   83807.86                1
# 2              502   France  Female   42       8  159660.80                3
# 3              699   France  Female   39       1       0.00                2
# 4              850    Spain  Female   43       2  125510.82                1
# ...            ...      ...     ...  ...     ...        ...              ...
# 9995           771   France    Male   39       5       0.00                2
# 9996           516   France    Male   35      10   57369.61                1
# 9997           709   France  Female   36       7       0.00                1
# 9998           772  Germany    Male   42       3   75075.31                2
# 9999           792   France  Female   28       4  130142.79                1
#
# ...

# %%
# encoding the gender column using label encoder
label_encoder = LabelEncoder()
data['gender'] = label_encoder.fit_transform(data['gender'])
data
# Out:
#       credit_score  country  gender  age  tenure    balance  products_number  \
# 0              619   France       0   42       2       0.00                1
# 1              608    Spain       0   41       1   83807.86                1
# 2              502   France       0   42       8  159660.80                3
# 3              699   France       0   39       1       0.00                2
# 4              850    Spain       0   43       2  125510.82                1
# ...            ...      ...     ...  ...     ...        ...              ...
# 9995           771   France       1   39       5       0.00                2
# 9996           516   France       1   35      10   57369.61                1
# 9997           709   France       0   36       7       0.00                1
# 9998           772  Germany       1   42       3   75075.31                2
# 9999           792   France       0   28       4  130142.79                1
#
# ...

# %%
# encoding the country column using label encoder

data['country'] = label_encoder.fit_transform(data['country'])
data
# Out:
#       credit_score  country  gender  age  tenure    balance  products_number  \
# 0              619        0       0   42       2       0.00                1
# 1              608        2       0   41       1   83807.86                1
# 2              502        0       0   42       8  159660.80                3
# 3              699        0       0   39       1       0.00                2
# 4              850        2       0   43       2  125510.82                1
# ...            ...      ...     ...  ...     ...        ...              ...
# 9995           771        0       1   39       5       0.00                2
# 9996           516        0       1   35      10   57369.61                1
# 9997           709        0       0   36       7       0.00                1
# 9998           772        1       1   42       3   75075.31                2
# 9999           792        0       0   28       4  130142.79                1
#
# ...

# %%
X = data.iloc[: , :-1]
y = data.iloc[: , -1]

# %%
# Standard scaling 
scaler = StandardScaler()
scaled_data = scaler.fit_transform(X)
X_scaled = pd.DataFrame(scaled_data, columns=X.columns)
X_scaled
# Out:
#       credit_score   country    gender       age    tenure   balance  \
# 0        -0.326221 -0.901886 -1.095988  0.293517 -1.041760 -1.225848
# 1        -0.440036  1.515067 -1.095988  0.198164 -1.387538  0.117350
# 2        -1.536794 -0.901886 -1.095988  0.293517  1.032908  1.333053
# 3         0.501521 -0.901886 -1.095988  0.007457 -1.387538 -1.225848
# 4         2.063884  1.515067 -1.095988  0.388871 -1.041760  0.785728
# ...            ...       ...       ...       ...       ...       ...
# 9995      1.246488 -0.901886  0.912419  0.007457 -0.004426 -1.225848
# 9996     -1.391939 -0.901886  0.912419 -0.373958  1.724464 -0.306379
# 9997      0.604988 -0.901886 -1.095988 -0.278604  0.687130 -1.225848
# 9998      1.256835  0.306591  0.912419  0.293517 -0.695982 -0.022608
# 9999      1.463771 -0.901886 -1.095988 -1.041433 -0.350204  0.859965
#
#       products_number  credit_card  active_member  estimated_salary
# 0           -0.911583     0.646092       0.970243          0.021886
# ...

# %%
# split the data into train and test dataset 
X_train, X_test, y_train, y_test = train_test_split(X_scaled , y, test_size=0.2, random_state=64)

# %% [markdown]
# ### ANN Model

# %%
model = Sequential([
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid') 
])

# %%
# Compile the model
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 471us/step - accuracy: 0.7333 - loss: 0.5354 - val_accuracy: 0.8194 - val_loss: 0.4238
# Epoch 2/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 270us/step - accuracy: 0.8411 - loss: 0.3925 - val_accuracy: 0.8431 - val_loss: 0.3899
# Epoch 3/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 270us/step - accuracy: 0.8551 - loss: 0.3642 - val_accuracy: 0.8381 - val_loss: 0.3835
# Epoch 4/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 259us/step - accuracy: 0.8573 - loss: 0.3489 - val_accuracy: 0.8456 - val_loss: 0.3746
# Epoch 5/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 262us/step - accuracy: 0.8632 - loss: 0.3415 - val_accuracy: 0.8462 - val_loss: 0.3728
# Epoch 6/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 266us/step - accuracy: 0.8642 - loss: 0.3317 - val_accuracy: 0.8469 - val_loss: 0.3687
# Epoch 7/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 267us/step - accuracy: 0.8648 - loss: 0.3302 - val_accuracy: 0.8469 - val_loss: 0.3699
# Epoch 8/50
# ...

# %%
# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(X_test, y_test)

print(f"Test accuracy: {test_accuracy:.4f}")
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 230us/step - accuracy: 0.8405 - loss: 0.3882
# Test accuracy: 0.8445

# %% [markdown]
# ### The model shows strong performance with 89% accuracy on the training dataset and 84-85% accuracy on the testing dataset, demonstrating its effectiveness and practicality in predicting customer retention.

# %%
y_pred_prob = model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int).flatten()
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 256us/step

# %% [markdown]
# Confusion Matrix

# %%
cm = confusion_matrix(y_test, y_pred)
cmd = ConfusionMatrixDisplay(cm, display_labels=['Class 0', 'Class 1'])

# Plot the confusion matrix
cmd.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.show()
